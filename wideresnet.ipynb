# %% [markdown]
# Wide Residual Networks (WRN)
#
# Paper link: https://arxiv.org/pdf/1605.07146
#
# -  decrease depth and increase width of residual networks
#
# Problem: As gradient flows through the network there is nothing to force it to go through residual block weights and it can avoid learning anything during training, so it is possible that there is either only a few
# blocks that learn useful representations, or many blocks share very little information with
# small contribution to the final goal.
#
# - Instead, we argue here that dropout should be inserted between convolutional layers.

# %%
import torch
from torch.utils.data import DataLoader
from torch import nn
from collections import OrderedDict
from torchvision import transforms, datasets
from torch.utils.data import Subset

'''
3 groups of 4 blocks
'''

class Block(nn.Module):
    def __init__(self, in_channel, num_filters, stride=1):
        super().__init__()

        self.layers = nn.Sequential(
            nn.BatchNorm2d(in_channel),
            nn.ReLU(),
            nn.Conv2d(in_channel, num_filters, kernel_size=3, padding=1, stride=stride),
            nn.Dropout(0.3),

            nn.BatchNorm2d(num_filters),
            nn.ReLU(),
            nn.Conv2d(num_filters, num_filters, kernel_size=3, padding=1, stride=1),
        )

        if stride != 1 or in_channel != num_filters:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channel, num_filters, kernel_size=(1, 1), stride=stride),
                nn.BatchNorm2d(num_filters)
            )
        else:
            self.shortcut = nn.Identity()

    def forward(self, x):
        x = self.layers(x) + self.shortcut(x)
        return x

class WideResNet(nn.Module):
    def __init__(self):
        super().__init__()

        self.layers = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=3, padding=1),

            Block(16, 80),
            Block(80, 80),
            Block(80, 80),
            Block(80, 80),

            Block(80, 160, stride=2),
            Block(160, 160),
            Block(160, 160),
            Block(160, 160),       

            Block(160, 320, stride=2),
            Block(320, 320),
            Block(320, 320),
            Block(320, 320),     
        )

        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.linear = nn.Linear(320, 100)

    def forward(self, x):
        x = self.layers(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

# %%
torch.backends.cudnn.benchmark = True
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True
torch.set_float32_matmul_precision('high')

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

if torch.cuda.is_available():
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
    torch.cuda.empty_cache()

train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5071, 0.4865, 0.4409], std=[0.2673, 0.2564, 0.2761]),
    transforms.RandomErasing(p=0.25)
])

test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5071, 0.4867, 0.4408], std=[0.2675, 0.2565, 0.2761])
])

# Load raw datasets
cifar_train_raw = datasets.CIFAR100(root="./data", train=True, download=True, transform=None)

train_size = int(0.9 * len(cifar_train_raw))  # 48,000

train_indices = list(range(0, train_size))
val_indices = list(range(train_size, len(cifar_train_raw)))

# Create datasets with appropriate transforms
cifar_train = Subset(
    datasets.CIFAR100(root="./data", train=True, transform=train_transform),
    train_indices
)
cifar_val = Subset(
    datasets.CIFAR100(root="./data", train=True, transform=test_transform),
    val_indices
)
# Use original test set (10,000 samples) - close to 10% of 60,000
cifar_test = datasets.CIFAR100(root="./data", train=False, transform=test_transform)

train_loader = DataLoader(
    cifar_train,
    batch_size=128,   # was 1024
    shuffle=True,
    num_workers=2,
    pin_memory=True,
    persistent_workers=False,  # free worker memory
    prefetch_factor=2
)
val_loader = DataLoader(
    cifar_val,
    batch_size=128,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
    persistent_workers=False,
    prefetch_factor=2
)
test_loader = DataLoader(
    cifar_test,
    batch_size=128,
    shuffle=False,
    num_workers=2,
    pin_memory=True,
    persistent_workers=False,
    prefetch_factor=2
)

num_classes = 100

def init_weights(m):
    if isinstance(m, nn.Conv2d):
        nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
        if m.bias is not None:
            nn.init.constant_(m.bias, 0)
    elif isinstance(m, nn.Linear):
        nn.init.normal_(m.weight, 0, 0.01)
        nn.init.constant_(m.bias, 0)

model = WideResNet().to(device)
model.apply(init_weights)

num_epochs = 40
loss_function = nn.CrossEntropyLoss(label_smoothing=0.1)
base_lr = 4e-3

batch_scale = 1024 / 256  # 4x larger batches
scaled_lr = base_lr * batch_scale**0.5  # Square root scaling

optimizer = torch.optim.SGD(model.parameters(), lr=0.05, momentum=0.9, weight_decay=5e-4)

scheduler = torch.optim.lr_scheduler.MultiStepLR(
    optimizer,
    milestones=[60, 120, 160],  # Decay at these epochs
    gamma=0.2  # Multiply LR by 0.2
)

best_val_loss = float('inf')

print(f"Model parameters: {sum(p.numel() for p in model.parameters()):,}")

for epoch in range(num_epochs):
    print(f'Starting Epoch {epoch+1}')
    model.train()

    current_loss = 0.0
    num_batches = 0

    for i, data in enumerate(train_loader):
        inputs, targets = data
        inputs, targets = inputs.to(device), targets.to(device)
            
        outputs = model(inputs)
        loss = loss_function(outputs, targets)
        loss.backward()

        optimizer.step()
        optimizer.zero_grad(set_to_none=True)

        current_loss += loss.item()
        num_batches += 1

        if i % 50 == 0:
            print(f'Batch {i}/{len(train_loader)}, Loss: {loss.item():.4f}')

    scheduler.step()

    avg_train_loss = current_loss / num_batches
    print(f'Epoch {epoch+1} finished')
    print(f'Training - Loss: {avg_train_loss:.4f}')

    if (epoch + 1) % 2 == 0:
        model.eval()
        val_loss = 0.0
        val_batches = 0

        print(f'Epoch {epoch+1} finished')
        print(f'average training loss is {avg_train_loss:.4f}')

        with torch.no_grad():
            for val_data in val_loader:
                val_inputs, val_targets = val_data
                val_inputs, val_targets = val_inputs.to(device), val_targets.to(device)  # Convert inputs to FP16

                val_outputs = model(val_inputs)
                val_batch_loss = loss_function(val_outputs, val_targets)

                val_loss += val_batch_loss.item()
                val_batches += 1


        avg_val_loss = val_loss / val_batches

        print(f'Epoch {epoch+1} finished')
        print(f'Training - Loss: {avg_train_loss:.4f}')
        print(f'Validation - Loss: {avg_val_loss:.4f}')

if torch.cuda.is_available():
    torch.cuda.empty_cache()
# Out:
# Using device: cuda
# GPU Memory: 15.8 GB
# Model parameters: 9,167,060
# Starting Epoch 1
# Batch 0/352, Loss: 4.6118
# Batch 50/352, Loss: 4.4278
# Batch 100/352, Loss: 4.4706
# Batch 150/352, Loss: 4.2365
# Batch 200/352, Loss: 4.0307
# Batch 250/352, Loss: 4.1028
# Batch 300/352, Loss: 4.0947
# Batch 350/352, Loss: 3.9276
# Epoch 1 finished
# Training - Loss: 4.2208
# Starting Epoch 2
# Batch 0/352, Loss: 3.9411
# Batch 50/352, Loss: 3.7867
# Batch 100/352, Loss: 3.9089
# Batch 150/352, Loss: 3.6704
# Batch 200/352, Loss: 3.6308
# Batch 250/352, Loss: 3.7144
# Batch 300/352, Loss: 3.5512
# Batch 350/352, Loss: 3.5044
# Epoch 2 finished
# Training - Loss: 3.7397
# Epoch 2 finished
# average training loss is 3.7397
# Epoch 2 finished
# Training - Loss: 3.7397
# Validation - Loss: 4.3242
# Starting Epoch 3
# Batch 0/352, Loss: 3.2788
# Batch 50/352, Loss: 3.3816
# Batch 100/352, Loss: 3.4168
# Batch 150/352, Loss: 3.3153
# Batch 200/352, Loss: 3.2366
# Batch 250/352, Loss: 3.3187
# Batch 300/352, Loss: 3.2061
# Batch 350/352, Loss: 3.0805
# Epoch 3 finished
# Training - Loss: 3.3751
# Starting Epoch 4
# Batch 0/352, Loss: 3.4497
# Batch 50/352, Loss: 3.3581
# Batch 100/352, Loss: 3.1778
# Batch 150/352, Loss: 3.1714
# Batch 200/352, Loss: 3.0476
# Batch 250/352, Loss: 3.1555
# Batch 300/352, Loss: 3.0167
# Batch 350/352, Loss: 3.1224
# Epoch 4 finished
# Training - Loss: 3.1268
# Epoch 4 finished
# average training loss is 3.1268
# Epoch 4 finished
# Training - Loss: 3.1268
# Validation - Loss: 3.6030
# Starting Epoch 5
# Batch 0/352, Loss: 2.8498
# Batch 50/352, Loss: 3.0669
# Batch 100/352, Loss: 2.8638
# Batch 150/352, Loss: 2.9457
# Batch 200/352, Loss: 2.9487
# Batch 250/352, Loss: 2.9193
# Batch 300/352, Loss: 2.7547
# Batch 350/352, Loss: 2.7034
# Epoch 5 finished
# Training - Loss: 2.9369
# Starting Epoch 6
# Batch 0/352, Loss: 2.9278
# Batch 50/352, Loss: 2.9558
# Batch 100/352, Loss: 2.9100
# Batch 150/352, Loss: 2.8180
# Batch 200/352, Loss: 2.6074
# Batch 250/352, Loss: 2.7694
# Batch 300/352, Loss: 2.7835
# Batch 350/352, Loss: 2.5839
# Epoch 6 finished
# Training - Loss: 2.7710
# Epoch 6 finished
# average training loss is 2.7710
# Epoch 6 finished
# Training - Loss: 2.7710
# Validation - Loss: 3.0135
# Starting Epoch 7
# Batch 0/352, Loss: 2.7729
# Batch 50/352, Loss: 2.5435
# Batch 100/352, Loss: 2.5541
# Batch 150/352, Loss: 2.6467
# Batch 200/352, Loss: 2.7067
# Batch 250/352, Loss: 2.8482
# Batch 300/352, Loss: 2.6329
# Batch 350/352, Loss: 2.6550
# Epoch 7 finished
# Training - Loss: 2.6511
# Starting Epoch 8
# Batch 0/352, Loss: 2.6045
# Batch 50/352, Loss: 2.7370
# Batch 100/352, Loss: 2.5813
# Batch 150/352, Loss: 2.6220
# Batch 200/352, Loss: 2.5965
# Batch 250/352, Loss: 2.6004
# Batch 300/352, Loss: 2.6650
# Batch 350/352, Loss: 2.6139
# Epoch 8 finished
# Training - Loss: 2.5454
# Epoch 8 finished
# average training loss is 2.5454
# Epoch 8 finished
# Training - Loss: 2.5454
# Validation - Loss: 2.8880
# Starting Epoch 9
# Batch 0/352, Loss: 2.3290
# Batch 50/352, Loss: 2.4644
# Batch 100/352, Loss: 2.5097
# Batch 150/352, Loss: 2.4045
# Batch 200/352, Loss: 2.4261
# Batch 250/352, Loss: 2.6308
# Batch 300/352, Loss: 2.4530
# Batch 350/352, Loss: 2.5804
# Epoch 9 finished
# Training - Loss: 2.4596
# Starting Epoch 10
# Batch 0/352, Loss: 2.2980
# Batch 50/352, Loss: 2.4051
# Batch 100/352, Loss: 2.3565
# Batch 150/352, Loss: 2.4269
# Batch 200/352, Loss: 2.2316
# Batch 250/352, Loss: 2.2524
# Batch 300/352, Loss: 2.3494
# Batch 350/352, Loss: 2.3468
# Epoch 10 finished
# Training - Loss: 2.3891
# Epoch 10 finished
# average training loss is 2.3891
# Epoch 10 finished
# Training - Loss: 2.3891
# Validation - Loss: 2.7239
# Starting Epoch 11
# Batch 0/352, Loss: 2.2992
# Batch 50/352, Loss: 2.1220
# Batch 100/352, Loss: 2.4637
# Batch 150/352, Loss: 2.6226
# Batch 200/352, Loss: 2.3888
# Batch 250/352, Loss: 2.4566
# Batch 300/352, Loss: 2.2749
# Batch 350/352, Loss: 2.2977
# Epoch 11 finished
# Training - Loss: 2.3218
# Starting Epoch 12
# Batch 0/352, Loss: 2.2517
# Batch 50/352, Loss: 2.0961
# Batch 100/352, Loss: 2.4108
# Batch 150/352, Loss: 2.2898
# Batch 200/352, Loss: 2.1931
# Batch 250/352, Loss: 2.1349
# Batch 300/352, Loss: 2.2680
# Batch 350/352, Loss: 2.2996
# Epoch 12 finished
# Training - Loss: 2.2746
# Epoch 12 finished
# average training loss is 2.2746
# Epoch 12 finished
# Training - Loss: 2.2746
# Validation - Loss: 2.7094
# Starting Epoch 13
# Batch 0/352, Loss: 1.9394
# Batch 50/352, Loss: 2.2173
# Batch 100/352, Loss: 2.1870
# Batch 150/352, Loss: 2.3381
# Batch 200/352, Loss: 2.1795
# Batch 250/352, Loss: 2.2948
# Batch 300/352, Loss: 2.1553
# Batch 350/352, Loss: 2.2321
# Epoch 13 finished
# Training - Loss: 2.2264
# Starting Epoch 14
# Batch 0/352, Loss: 2.2457
# Batch 50/352, Loss: 2.2145
# Batch 100/352, Loss: 2.0378
# Batch 150/352, Loss: 2.0901
# Batch 200/352, Loss: 2.1818
# Batch 250/352, Loss: 2.1611
# Batch 300/352, Loss: 2.1310
# Batch 350/352, Loss: 2.1699
# Epoch 14 finished
# Training - Loss: 2.1841
# Epoch 14 finished
# average training loss is 2.1841
# Epoch 14 finished
# Training - Loss: 2.1841
# Validation - Loss: 2.3224
# Starting Epoch 15
# Batch 0/352, Loss: 2.1416
# Batch 50/352, Loss: 2.1732
# Batch 100/352, Loss: 2.1374
# Batch 150/352, Loss: 2.2924
# Batch 200/352, Loss: 2.0851
# Batch 250/352, Loss: 2.2844
# Batch 300/352, Loss: 2.2662
# Batch 350/352, Loss: 2.3340
# Epoch 15 finished
# Training - Loss: 2.1469
# Starting Epoch 16
# Batch 0/352, Loss: 2.0566
# Batch 50/352, Loss: 2.1923
# Batch 100/352, Loss: 2.2998
# Batch 150/352, Loss: 2.1666
# Batch 200/352, Loss: 2.0617
# Batch 250/352, Loss: 2.1069
# Batch 300/352, Loss: 2.0041
# Batch 350/352, Loss: 2.2535
# Epoch 16 finished
# Training - Loss: 2.1247
# Epoch 16 finished
# average training loss is 2.1247
# Epoch 16 finished
# Training - Loss: 2.1247
# Validation - Loss: 2.2364
# Starting Epoch 17
# Batch 0/352, Loss: 2.0070
# Batch 50/352, Loss: 2.0600
# Batch 100/352, Loss: 2.2757
# Batch 150/352, Loss: 2.0184
# Batch 200/352, Loss: 2.0428
# Batch 250/352, Loss: 2.0097
# Batch 300/352, Loss: 2.0122
# Batch 350/352, Loss: 2.1198
# Epoch 17 finished
# Training - Loss: 2.0987
# Starting Epoch 18
# Batch 0/352, Loss: 2.0862
# Batch 50/352, Loss: 2.2834
# Batch 100/352, Loss: 2.0254
# Batch 150/352, Loss: 2.0743
# Batch 200/352, Loss: 2.0804
# Batch 250/352, Loss: 2.2460
# Batch 300/352, Loss: 2.0304
# Batch 350/352, Loss: 2.0911
# Epoch 18 finished
# Training - Loss: 2.0799
# Epoch 18 finished
# average training loss is 2.0799
# Epoch 18 finished
# Training - Loss: 2.0799
# Validation - Loss: 2.2611
# Starting Epoch 19
# Batch 0/352, Loss: 2.0235
# Batch 50/352, Loss: 1.9786
# Batch 100/352, Loss: 1.8310
# Batch 150/352, Loss: 1.8365
# Batch 200/352, Loss: 1.9568
# Batch 250/352, Loss: 1.9565
# Batch 300/352, Loss: 2.2647
# Batch 350/352, Loss: 2.0115
# Epoch 19 finished
# Training - Loss: 2.0621
# Starting Epoch 20
# Batch 0/352, Loss: 1.9343
# Batch 50/352, Loss: 1.9483
# Batch 100/352, Loss: 1.9904
# Batch 150/352, Loss: 2.2605
# Batch 200/352, Loss: 1.8478
# Batch 250/352, Loss: 2.0641
# Batch 300/352, Loss: 2.1915
# Batch 350/352, Loss: 2.0579
# Epoch 20 finished
# Training - Loss: 2.0360
# Epoch 20 finished
# average training loss is 2.0360
# Epoch 20 finished
# Training - Loss: 2.0360
# Validation - Loss: 2.1585
# Starting Epoch 21
# Batch 0/352, Loss: 2.0201
# Batch 50/352, Loss: 1.9423
# Batch 100/352, Loss: 2.1501
# Batch 150/352, Loss: 1.9367
# Batch 200/352, Loss: 2.3160
# Batch 250/352, Loss: 2.1858
# Batch 300/352, Loss: 1.9029
# Batch 350/352, Loss: 2.0898
# Epoch 21 finished
# Training - Loss: 2.0171
# Starting Epoch 22
# Batch 0/352, Loss: 1.9110
# Batch 50/352, Loss: 1.8413
# Batch 100/352, Loss: 1.9640
# Batch 150/352, Loss: 1.9819
# Batch 200/352, Loss: 1.9218
# Batch 250/352, Loss: 1.8515
# Batch 300/352, Loss: 2.0945
# Batch 350/352, Loss: 2.0091
# Epoch 22 finished
# Training - Loss: 2.0013
# Epoch 22 finished
# average training loss is 2.0013
# Epoch 22 finished
# Training - Loss: 2.0013
# Validation - Loss: 2.3901
# Starting Epoch 23
# Batch 0/352, Loss: 2.1399
# Batch 50/352, Loss: 2.1711
# Batch 100/352, Loss: 2.1209
# Batch 150/352, Loss: 2.0160
# Batch 200/352, Loss: 2.2198
# Batch 250/352, Loss: 2.1524
# Batch 300/352, Loss: 2.1118
# Batch 350/352, Loss: 2.0645
# Epoch 23 finished
# Training - Loss: 1.9819
# Starting Epoch 24
# Batch 0/352, Loss: 1.9896
# Batch 50/352, Loss: 2.0157
# Batch 100/352, Loss: 1.9702
# Batch 150/352, Loss: 2.1006
# Batch 200/352, Loss: 1.9557
# Batch 250/352, Loss: 1.9541
# Batch 300/352, Loss: 1.9019
# Batch 350/352, Loss: 1.9269
# Epoch 24 finished
# Training - Loss: 1.9601
# Epoch 24 finished
# average training loss is 1.9601
# Epoch 24 finished
# Training - Loss: 1.9601
# Validation - Loss: 2.2515
# Starting Epoch 25
# Batch 0/352, Loss: 1.8090
# Batch 50/352, Loss: 1.8290
# Batch 100/352, Loss: 1.8239
# Batch 150/352, Loss: 1.9745
# Batch 200/352, Loss: 2.1701
# Batch 250/352, Loss: 2.0550
# Batch 300/352, Loss: 1.9079
# Batch 350/352, Loss: 2.0354
# Epoch 25 finished
# Training - Loss: 1.9576
# Starting Epoch 26
# Batch 0/352, Loss: 1.7690
# Batch 50/352, Loss: 2.0107
# Batch 100/352, Loss: 1.8620
# Batch 150/352, Loss: 1.6941
# Batch 200/352, Loss: 1.9994
# Batch 250/352, Loss: 1.9671
# Batch 300/352, Loss: 1.9554
# Batch 350/352, Loss: 2.1124
# Epoch 26 finished
# Training - Loss: 1.9307
# Epoch 26 finished
# average training loss is 1.9307
# Epoch 26 finished
# Training - Loss: 1.9307
# Validation - Loss: 2.2262
# Starting Epoch 27
# Batch 0/352, Loss: 1.7790
# Batch 50/352, Loss: 1.7608
# Batch 100/352, Loss: 1.8615
# Batch 150/352, Loss: 2.0025
# Batch 200/352, Loss: 1.9467
# Batch 250/352, Loss: 1.7112
# Batch 300/352, Loss: 1.8875
# Batch 350/352, Loss: 1.9036
# Epoch 27 finished
# Training - Loss: 1.9229
# Starting Epoch 28
# Batch 0/352, Loss: 1.9664
# Batch 50/352, Loss: 1.9234
# Batch 100/352, Loss: 2.1481
# Batch 150/352, Loss: 1.9509
# Batch 200/352, Loss: 1.9532
# Batch 250/352, Loss: 1.8809
# Batch 300/352, Loss: 2.0565
# Batch 350/352, Loss: 1.9974
# Epoch 28 finished
# Training - Loss: 1.9087
# Epoch 28 finished
# average training loss is 1.9087
# Epoch 28 finished
# Training - Loss: 1.9087
# Validation - Loss: 2.1875
# Starting Epoch 29
# Batch 0/352, Loss: 2.0089
# Batch 50/352, Loss: 1.7300
# Batch 100/352, Loss: 2.0366
# Batch 150/352, Loss: 1.9081
# Batch 200/352, Loss: 1.7743
# Batch 250/352, Loss: 1.8117
# Batch 300/352, Loss: 1.9603
# Batch 350/352, Loss: 1.8879
# Epoch 29 finished
# Training - Loss: 1.9039
# Starting Epoch 30
# Batch 0/352, Loss: 1.8467
# Batch 50/352, Loss: 1.8319
# Batch 100/352, Loss: 1.8499
# Batch 150/352, Loss: 1.7425
# Batch 200/352, Loss: 1.9168
# Batch 250/352, Loss: 1.8322
# Batch 300/352, Loss: 1.9170
# Batch 350/352, Loss: 1.8584
# Epoch 30 finished
# Training - Loss: 1.8851
# Epoch 30 finished
# average training loss is 1.8851
# Epoch 30 finished
# Training - Loss: 1.8851
# Validation - Loss: 2.2066
# Starting Epoch 31
# Batch 0/352, Loss: 1.7996
# Batch 50/352, Loss: 1.8582
# Batch 100/352, Loss: 1.9740
# Batch 150/352, Loss: 2.0298
# Batch 200/352, Loss: 1.8308
# Batch 250/352, Loss: 1.7433
# Batch 300/352, Loss: 2.0300
# Batch 350/352, Loss: 1.8807
# Epoch 31 finished
# Training - Loss: 1.8803
# Starting Epoch 32
# Batch 0/352, Loss: 1.9079
# Batch 50/352, Loss: 1.6609
# Batch 100/352, Loss: 1.6894
# Batch 150/352, Loss: 1.9907
# Batch 200/352, Loss: 2.1193
# Batch 250/352, Loss: 1.9771
# Batch 300/352, Loss: 1.9162
# Batch 350/352, Loss: 1.9019
# Epoch 32 finished
# Training - Loss: 1.8662
# Epoch 32 finished
# average training loss is 1.8662
# Epoch 32 finished
# Training - Loss: 1.8662
# Validation - Loss: 2.2722
# Starting Epoch 33
# Batch 0/352, Loss: 1.9285
# Batch 50/352, Loss: 1.8014
# Batch 100/352, Loss: 1.8273
# Batch 150/352, Loss: 1.9364
# Batch 200/352, Loss: 1.8044
# Batch 250/352, Loss: 1.9802
# Batch 300/352, Loss: 1.8875
# Batch 350/352, Loss: 1.9260
# Epoch 33 finished
# Training - Loss: 1.8586
# Starting Epoch 34
# Batch 0/352, Loss: 1.9732
# Batch 50/352, Loss: 1.8478
# Batch 100/352, Loss: 1.7356
# Batch 150/352, Loss: 1.8881
# Batch 200/352, Loss: 2.0204
# Batch 250/352, Loss: 1.9507
# Batch 300/352, Loss: 1.9189
# Batch 350/352, Loss: 1.7459
# Epoch 34 finished
# Training - Loss: 1.8500
# Epoch 34 finished
# average training loss is 1.8500
# Epoch 34 finished
# Training - Loss: 1.8500
# Validation - Loss: 2.2366
# Starting Epoch 35
# Batch 0/352, Loss: 1.8994
# Batch 50/352, Loss: 1.7367
# Batch 100/352, Loss: 1.7681
# Batch 150/352, Loss: 1.8300
# Batch 200/352, Loss: 1.7356
# Batch 250/352, Loss: 1.9069
# Batch 300/352, Loss: 1.7155
# Batch 350/352, Loss: 1.8368
# Epoch 35 finished
# Training - Loss: 1.8371
# Starting Epoch 36
# Batch 0/352, Loss: 1.7536
# Batch 50/352, Loss: 1.6872
# Batch 100/352, Loss: 1.7266
# Batch 150/352, Loss: 1.9311
# Batch 200/352, Loss: 1.7009
# Batch 250/352, Loss: 1.7564
# Batch 300/352, Loss: 1.7783
# Batch 350/352, Loss: 1.8133
# Epoch 36 finished
# Training - Loss: 1.8347
# Epoch 36 finished
# average training loss is 1.8347
# Epoch 36 finished
# Training - Loss: 1.8347
# Validation - Loss: 2.1032
# Starting Epoch 37
# Batch 0/352, Loss: 1.6515
# Batch 50/352, Loss: 1.8407
# Batch 100/352, Loss: 1.8139
# Batch 150/352, Loss: 1.8817
# Batch 200/352, Loss: 1.7898
# Batch 250/352, Loss: 1.8517
# Batch 300/352, Loss: 1.8286
# Batch 350/352, Loss: 1.9173
# Epoch 37 finished
# Training - Loss: 1.8261
# Starting Epoch 38
# Batch 0/352, Loss: 1.7436
# Batch 50/352, Loss: 1.9972
# Batch 100/352, Loss: 1.8270
# Batch 150/352, Loss: 1.9313
# Batch 200/352, Loss: 1.8306
# Batch 250/352, Loss: 1.9380
# Batch 300/352, Loss: 1.8814
# Batch 350/352, Loss: 1.9084
# Epoch 38 finished
# Training - Loss: 1.8173
# Epoch 38 finished
# average training loss is 1.8173
# Epoch 38 finished
# Training - Loss: 1.8173
# Validation - Loss: 2.1427
# Starting Epoch 39
# Batch 0/352, Loss: 1.7883
# Batch 50/352, Loss: 1.7841
# Batch 100/352, Loss: 1.7659
# Batch 150/352, Loss: 1.7353
# Batch 200/352, Loss: 1.8602
# Batch 250/352, Loss: 1.6255
# Batch 300/352, Loss: 1.8280
# Batch 350/352, Loss: 1.8892
# Epoch 39 finished
# Training - Loss: 1.8066
# Starting Epoch 40
# Batch 0/352, Loss: 1.7144
# Batch 50/352, Loss: 1.6626
# Batch 100/352, Loss: 1.6279
# Batch 150/352, Loss: 1.8259
# Batch 200/352, Loss: 1.8903
# Batch 250/352, Loss: 1.6726
# Batch 300/352, Loss: 1.9234
# Batch 350/352, Loss: 1.7524
# Epoch 40 finished
# Training - Loss: 1.8097
# Epoch 40 finished
# average training loss is 1.8097
# Epoch 40 finished
# Training - Loss: 1.8097
# Validation - Loss: 2.3876

# %%
def evaluate_test_set(model):
    model.eval()
    correct = 0
    total = 0
    
    print("Starting evaluation...")
    
    with torch.no_grad():
        for data in test_loader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            
            # Use autocast for consistency if you trained with it
            outputs = model(images)
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print(f'Accuracy of the network on the test images: {accuracy:.2f}%')
    return accuracy

print("\n=== Running standard evaluation ===")
standard_accuracy = evaluate_test_set(model)   
print(f'Standard Test Accuracy: {standard_accuracy:.4f} ({standard_accuracy:.2f}%)')
# Out:
# === Running standard evaluation ===
# Starting evaluation...
# Accuracy of the network on the test images: 56.35%
# Standard Test Accuracy: 56.3500 (56.35%)
